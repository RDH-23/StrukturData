# %% [markdown]
# # **Graph**

# %% [markdown]
# *Graph* adalah jaringan yang terdiri dari node (atau *vertex*, V) yang terhubung dengan edge (atau *arc*, E). Graph dapat didefinisikan sebagai sepasang set dari $G=(V,E)$, di mana V adalah vertex/node/titik, dan E adalah edge/arc atau set node pasangannya.
# <br>Sebagai contoh, set node dan set pasangannya
# <br>𝐸 = {{𝑎, 𝑏}, {𝑏, 𝑐}, {𝑐, 𝑑}, {𝑑, 𝑎}}.
# <br>Gambar berikut adalah ilustrasi dari Graph.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Gambar 1. Graph**

# %% [markdown]
# <a id="menu"></a>
# Berikut akan dijelaskan mengenai :
# 1. [Istilah dalam Graph](#istilah)
# 2. [Jenis-Jenis Graph](#jenis)

# %% [markdown]
# <a id="istilah"></a>
# ## **Istilah dalam Graph**

# %% [markdown]
# Beberapa istilah yang terdapat dalam *graph*, antara lain:
# * **Vertex (V)** Bagian paling dasar dari grafik atau yang disebut juga sebagai node/titik.
# * **Edge (E)** Bagian dari graph yang menghubungkan 2 vertex/node/titik.
# * **Weight (W)** Sebuah nilai dalam graph atau yang menunjukan biaya yang dibutuhkan untuk berpindah dari satu titik ke titik yang lain.
# * **Path** Serangkaian vertex yang berbeda-beda yang berdekatan dihubungkan oleh edge dan berturut-turut dari vertex satu ke vertex berikutnya.

# %% [markdown]
# Gambar 2 berikut menunjukan beberapa istilah dalam graph.
#
# ![image.png](attachment:image.png)
#
# **Gambar 2. Istilah dalam Graph**

# %% [markdown]
# [Kembali ke Menu Awal](#menu)

# %% [markdown]
# <a id="jenis"></a>
# ## **Jenis Graph**

# %% [markdown]
# Bentuk dari graph dibedakan menjadi beberapa jenis, antara lain: *Undirected Graph, Directed Graph, Weigthed Graph, Unweigthed Graph, Cyle Graph, Conected Graph, Unconeted Graph, dan Complete Graph*

# %% [markdown]
# ### **Undirected Graph**

# %% [markdown]
# Sebuah graph yang ujung – ujung dari edge tidak memiliki arah (atau tidak memiliki mata panah), dimana setiap ujung dari edge berlaku dua arah.
#
# Misalkan:
# <br>{$a$, $b$} Arah bisa dari $a$ ke $b$, atau $b$ ke $a$
# <br>$a-b$ terdiri dari {$a$, $b$} atau {$b$,$a$}
#
# ![image.png](attachment:image.png)
#
# **Gambar 3. Undirected Graph**<br>
# Maka notasi graph dari Gambar 3 adalah<br>
# $G=(V,E)$
# <br>$V$= {$a,b,c,d$}
# <br>$E$ = {{$a,b$},{$a,d$},{$b,c$},{$d,c$}}

# %% [markdown]
# ### **Directed Graph (Diagraph)**
#
# Sebuah *graph* yang ujung – ujung dari *edge* memiliki arah, dimana setiap ujung dari *edge* dalam *Digraph* memiliki anak panah yang mengarah ke vertex tertentu.
#
# Misalkan<br>
# {$a,b$} Arah dari $a$ ke $b$
# <br>$𝑎 → 𝑏$ terdiri dari {$a,b$}
#
# ![image.png](attachment:image.png)
#
# **Gambar 4. Directed Graph**<br>
# Maka notasi graph dari Gambar 4 adalah <br>
#
# $G=(V,E)$
# <br>$V$= {$a,b,c,d$}
# <br>$E$ = {{$a,b$},{$a,d$},{$b,c$},{$d,c$}}

# %% [markdown]
# ### **Weighted Graph dan Unweighted Graph**
#
#
# *Weigthed Graph* Sebuah graph dimana setiap edge memiliki nilai. Nilai tersebut adalah representasi dari bobot/biaya/weight dari edge tersebut. Bobot ini boleh lebih dari satu, semisal jarak antar kota, jumlah kendaraan yang melintasi kota tersebut, dll.
#
# ![image.png](attachment:image.png)
#
# **Gambar 5. Weighted Graph**
#
# Maka notasi graph dari Gambar 5 adalah<br>
# $G=(V,E)$
# <br>$V$= {$a,b,c,d$}
# <br>$E$ = {{$a,b,4$},{$a,d,5$},{$b,c,3$},{$d,c,6$}}
#
#
# Jumlah bobot dalam *weighted graph* adalah sejumlah nilai untuk semua *edge* dalam suatu *path*, seperti *path* dari $a$ ke $c$ maka jumlah bobotnya adalah 7.<br>
# Gambar 4 juga disebut *unweighted graph* maka jumlah bobotnya dihitung dari jumlahnya *edge*. Jika *path* dari a ke c maka bobotnya adalah 2.

# %% [markdown]
# ### **Cycle Graph**
#
# Sebuah *directed graph* dimana titik awal sama dengan titik tujuan. Atau sebuah *path* yang kembali kepada titik awal, misal path $(a,b,d,a)$
#
# ![image.png](attachment:image.png)
#
# **Gambar 6. Cycle Graph**

# %% [markdown]
# ### **Connected Graph dan Disconnected Graph**
#
# *Connected Graph *adalah sebuah *graph* dimana setiap vertex terhubung satu dengan lainnya,
# dalam *graph* tersebut tidak ada vertex yang tidak terhubung. Sedangkan *disconnected graph* jika
# salah satu vertex tidak terhubung dengan vertex lainnya, atau dapat dikatakan tidak ada jalur
# menuju vertex tersebut.<br>
# Gambar 7a adalah Connected Graph dan gambar 7b adalah *disconnected Graph.*
#
# ![image.png](attachment:image.png)
#
# **Gambar 7. (a)Connected Graph (b)Disconnected Graph**

# %% [markdown]
# ### **Complete Graph**
#
# *Completed Graph* adalah sebuah *graph* dimana semua vertex terhubung dengan lainnya, tidak
# ada edge yang terputus.<br>
# Gambar 3 dan 4 adalah contoh *Complete Graph*

# %% [markdown]
# [Kembali ke Menu Awal](#menu)
