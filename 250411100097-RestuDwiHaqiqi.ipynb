# %% [markdown]
# # **Struktur Data**

# %% [markdown]
# ## Definisi

# %% [markdown]
# Struktur data adalah cara kita menyimpan, mengatur, dan mengelola data di dalam memori (RAM) agar data tersebut dapat diakses dan dimodifikasi secara efisien oleh prosesor (CPU).

# %% [markdown]
# Struktur data adalah cara untuk mengorganisasi dan menyimpan data dalam komputer agar bisa digunakan secara efisien.

# %% [markdown]
# Struktur Data menrupakan cara progammer untuk mempresentasikan suatu data, dan memudahkan programmer untuk menyelesaikan permasalahan dengan menggunakan struktur data tersebut.

# %% [markdown]
# Contoh struktur data adalah Array, Linked List, Tree, dan Heap, sedangkan contoh algoritma adalah Binary Search, Quick Sort, dan Merge Sort.

# %% [markdown]
# ## Mengapa Pemilihan Struktur Data penting?

# %% [markdown]
# setiap struktur data memiliki kelebihan dan kekurangan. Misalnya, dalam python:
# * Jika butuh mentimpan data berupa berurutan dan sering diakses berdasarkan nomor urut (indeks), kita menggunakan **list**.
# * Jika butuh mencari data dengan sangat cepat berdasarkan "kunci" *(key)*, kita menggunakan **Dictionary**.

# %% [markdown]
# ## Struktur Data **Linear Structure**

# %% [markdown]
# Struktur data **Linear Structure** merupakan struktur data sederhana dimana ketika data ditambahkan maka data tersebut berada pada posisi relatif terhadap data yang lain dari struktur data tersebut. Linear structure ini memiliki dua buah ujung. Dua buah ujung ini memiliki beberapa istilah seperti **left-right**, **front-rear**, ataupun **top-bottom**. terdapat beberapa struktur data yang termasik pada linearr structure ini, yaitu :
# * Stacks
# * Queues
# * Lists
#
# Ketiga jenis struktur data tersebut berbeda dala penambahan atau penghapusan suatu data. Misalkan, suatu struktur data hanya diperbolehkan menghapus data pada salah satu ujung, sedangkan pada struktur data lain, penghapusan data dapat dilakukan pada kedua ujung.

# %% [markdown]
#  Berikut Pembahasan dari ketiga linear strcture:

# %% [markdown]
# ### [1. Stacks](<Materi2_(Stacks_Queues_Deques)/Stacks.ipynb>)

# %% [markdown]
# ### [2. Queues](<Materi2_(Stacks_Queues_Deques)/Queues.ipynb>)

# %% [markdown]
# ### [3. Deques](<Materi2_(Stacks_Queues_Deques)/Deques.ipynb>)

# %% [markdown]
# # **SORTING #1**

# %% [markdown]
# ## Pendahuluan: Mengapa Kita Membutuhkan Pengurutan (Sorting)?

# %% [markdown]
# Dalam dunia pemrograman dan analisis data, data tidak hanya sekadar diinput, tetapi juga butuh diolah agar kita dapat mengambil suatu analisa yang bermakna. Salah satu proses yang sangat penting dalam pengolahan data ini adalah proses pengurutan atau sorting.

# %% [markdown]
# Secara umum, proses pengurutan data dilakukan dengan membandingkan antara data yang satu dengan data yang lain. Sebagai contoh kasus yang nyata, misalkan kita memiliki kumpulan data mahasiswa. Terkadang kita membutuhkan data tersebut urut berdasarkan nilai atau penghasilan orang tua, sehingga dari data yang sudah terurut itu, kita dapat mengambil keputusan yang tepat, misalnya menentukan mahasiswa mana yang paling berhak menerima beasiswa.

# %% [markdown]
# Berikut tiga algoritma pengurutan dasar beserta implementasinya di Python, yaitu:

# %% [markdown]
# ### [1. Bubble Sort](<Materi3_(Bubble Sort_Selection_Sort_InsertionSort)/BubbleSort.ipynb>)

# %% [markdown]
# ### [2. Selection Sort](<Materi3_(Bubble Sort_Selection_Sort_InsertionSort)/SelectionSort.ipynb>)

# %% [markdown]
# ### [3. Insertion Sort](<Materi3_(Bubble Sort_Selection_Sort_InsertionSort)/InsertionSort.ipynb>)

# %% [markdown]
# # **REKURSIF**

# %% [markdown]
# ### [Rekursif](<Materi4_(Rekursif)/Rekursif.ipynb>)

# %% [markdown]
# # **Pencarian/Searching**

# %% [markdown]
# Pencarian data terkadang sangat diperlukan pada proses komputasi, sistem informasi, dan lainlain. Dengan pencarian data ini maka data yang diperlukan dapat diketahui posisinya terhadap
# kumpulan data yang lain, sehingga data ini dapat digunakan untuk proses berikutnya. Misalkan
# pada data mahasiswa, diperlukan data lengkap tentang mahasiswa dengan Nomor induk
# XXXXXX, maka diperlukan proses pencarian data tersebut dengan key berupa nomor induk
# mahasiswa. Data yang didapat ini dapat digunakan untuk keperluan yang lain, misalkan keperluan
# administratif.

# %% [markdown]
# Pada umumnya, proses pencarian data ini menghasilkan posisi data yang dicari terhadap
# keseluruhan data, akan tetapi untuk pencarian data yang sederhana, nilai True atau False saja
# yang dihasilkan, nilai ini menandakan apakah data berada di sekumpulan data ataukah tidak.
# Proses pencarian sederhana ini sudah disediakan oleh python dengan menggunakan syntax in,
# seperti contoh berikut:

# %%
a = [12, 5, 9, 8 , 1, 10, 26]

11 in a
# Out:
# False

# %%
12 in a
# Out:
# True

# %%
15 in a
# Out:
# False

# %% [markdown]
# ## **Algoritma Searching:**

# %% [markdown]
# ### [1. Sequential Search](<Materi5_(Searching)/SequentialSearch.ipynb>)

# %% [markdown]
# Pencarian dengan algoritma sequential search akan menemukan data dengan cepat jika data
# yang dicari terletak di indeks pertama dari suatu list data. Akan tetapi jika data yang dicari berada
# di posisi terakhir dari suatu list atau posisi lain, maka algoritma sequential search ini akan
# membutuhkan waktu yang lebih lama, karena algoritma ini akan mencari satu persatu, dimulai dari
# indeks pertama sampai dengan indeks terakhir.

# %% [markdown]
# ### [2. Binary Search](<Materi5_(Searching)/BinarySearch.ipynb>)

# %% [markdown]
# Sequential Search mencari data dengan cara membandingkan data yang dicari dengan setiap
# data yang terdapat pada list satu persatu dari indeks awal sampai dengan indeks terakhir.
# Sedangkan pada binary search, list data dibagi menjadi dua buah grup, dan pencarian akan
# dilakukan dengan cara membandingkan data yang dicari dengan data yang terdapat pada indeks
# tengah, jika data yang dicari lebih besar terhadap data yang terdapat pada indeks tengah, maka
# pencarian berikutnya hanya dilakukan pada grup terakhir saja. Hal ini dilakukan terus menerus
# (pembagian list menjadi dua buah grup, pembandingan data yang dicari dengan nilai tengah),
# sampai data diketemukan, atau data tidak diketemukan. Oleh karena itu waktu komputasi yang
# dibutuhkan untuk binary search lebih sedikit dibandingkan dengan sequential search, karena
# pencarian tidak dilakukan pada setiap data, tapi hanya grup yang memenuhi syarat saja.

# %% [markdown]
# ### [3. Hashing Search](<Materi5_(Searching)/HashingSearch.ipynb>)

# %% [markdown]
# # **SORTING #2**

# %% [markdown]
# Permasalahan sorting akan lebih mudah dilaksanakan jika hanya terdapat satu elemen saja yang
# akan diurutkan.
# Jika hanya terdapat satu elemen dalam sebuah list data, maka data tersebut otomatis sudah
# dalam keadaan terurut.

# %% [markdown]
# ### [1. Merge Sort](<Materi6_(MergeSort_QuickSort_CountingSort)/MergeSort.ipynb>)

# %% [markdown]
# ### [2. Quick Sort](<Materi6_(MergeSort_QuickSort_CountingSort)/QuickSort.ipynb>)

# %% [markdown]
# ### [3. Counting Sort](<Materi6_(MergeSort_QuickSort_CountingSort)/CountingSort.ipynb>)

# %% [markdown]
# # **LINKED LIST**

# %% [markdown]
# ### [1. Pengenalan Class-Object](<Materi7_(LinkedList)/PengenalanClass_Object.ipynb>)
